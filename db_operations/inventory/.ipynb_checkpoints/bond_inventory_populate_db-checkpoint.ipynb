# %%
import sys
import time
import math
import uuid
from datetime import date
from dateutil.relativedelta import relativedelta
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed

import pandas as pd
import mlflow
from domino.data_sources import DataSourceClient

# ─── CONFIG ───────────────────────────────────────────────────────────────────
EXPERIMENT_NAME = "Populate DB (bond_inventory)"
mlflow.set_experiment(EXPERIMENT_NAME)

BATCH_SIZE   = 1_000
MAX_WORKERS  = 8
ARTIFACT_DIR = "artifacts/results"

# ─── HELPERS ──────────────────────────────────────────────────────────────────
def find_mount_root(start: Path, target: str = "mnt") -> Path:
    p = start.resolve()
    while p.name != target and p.parent != p:
        p = p.parent
    if p.name != target:
        raise FileNotFoundError(f"‘{target}’ not found in {start}")
    return p

def sanitize_quantity(val):
    try:
        q = float(val)
        return 0.0 if (math.isnan(q) or math.isinf(q)) else round(q * 0.01, 2)
    except:
        return 0.0

def quote(val):
    if val is None:
        return "NULL"
    if isinstance(val, float) and (math.isnan(val) or math.isinf(val)):
        return "NULL"
    if hasattr(val, "tzinfo") and pd.isna(val):  # Timestamp check
        return "NULL"

    s = str(val)
    if s.strip().lower() in {"nan", "null", ""}:
        return "NULL"

    # escape single quotes by doubling them
    escaped = s.replace("'", "''")
    return "'{}'".format(escaped)

def chunks(seq, size):
    for i in range(0, len(seq), size):
        yield seq[i : i + size]

# ─── DATA & DB ────────────────────────────────────────────────────────────────
def fetch_active_bonds(ds, snapshot_date: date):
    sql = f"""
      SELECT *
        FROM treasury_auction_results
       WHERE security_type IN ('Note','Bill','Bond')
         AND issue_date   < '{snapshot_date}'
         AND maturity_date> '{snapshot_date}'
    """
    return ds.query(sql).to_pandas().to_dict(orient="records")

def upsert_inventory(ds, rows, snapshot_date: date):
    if not rows:
        mlflow.log_metric("rows_inserted", 0)
        return

    cols = [
      "inventory_date","cusip","quantity","security_type","security_term",
      "issue_date","maturity_date","int_rate","int_payment_frequency",
      "series","price_per100","auction_date"
    ]
    col_list = ", ".join(cols)
    set_list = ", ".join(f"{c}=EXCLUDED.{c}" for c in cols if c not in ("inventory_date","cusip"))

    for batch in chunks(rows, BATCH_SIZE):
        values = ["(" + ", ".join(quote(r.get(c)) for c in cols) + ")" for r in batch]
        template = """
        INSERT INTO bond_inventory ({col_list})
        VALUES
          {batch_values}
        ON CONFLICT (inventory_date, cusip) DO UPDATE SET
          {set_list};
        """
        sql = template.format(
          col_list    = col_list,
          batch_values= ",\n  ".join(values),
          set_list    = set_list
        )
        ds.query(sql)

# ─── WORKER ───────────────────────────────────────────────────────────────────
def run_snapshot(snapshot_date: date):
    # Give each thread its own DS/client
    ds = DataSourceClient().get_datasource("market_data")
    run_id = str(uuid.uuid4())
    with mlflow.start_run(run_name=f"Inventory {snapshot_date}", nested=True):
        mlflow.set_tag("snapshot_date", snapshot_date.isoformat())
        start = time.time()

        raw = fetch_active_bonds(ds, snapshot_date)
        mlflow.log_metric("rows_fetched", len(raw))

        # build inventory
        inv = []
        for r in raw:
            q = round(sanitize_quantity(r.get("comp_accepted")) / 1_000_000) * 5_000
            if q > 0 and r.get("cusip"):
                inv.append({
                    "inventory_date":  snapshot_date,
                    "cusip":           r["cusip"],
                    "quantity":        q,
                    "security_type":   r["security_type"],
                    "security_term":   r["security_term"],
                    "issue_date":      r["issue_date"],
                    "maturity_date":   r["maturity_date"],
                    "int_rate":        r["int_rate"],
                    "int_payment_frequency": r["int_payment_frequency"],
                    "series":          r["series"],
                    "price_per100":    r["price_per100"],
                    "auction_date":    r["auction_date"],
                })
        # dedupe
        seen = set()
        dedup = []
        for row in inv:
            key = (row["inventory_date"], row["cusip"])
            if key not in seen:
                seen.add(key)
                dedup.append(row)

        upsert_inventory(ds, dedup, snapshot_date)
        elapsed = time.time() - start
        mlflow.log_metric("rows_inserted", len(dedup))
        mlflow.log_metric("run_duration_sec", elapsed)

        # write out CSV and log artifact
        df = pd.DataFrame(dedup)
        mnt = find_mount_root(Path.cwd())
        out = mnt / ARTIFACT_DIR / f"bond_inventory_{snapshot_date}.csv"
        out.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(out, index=False)
        mlflow.log_artifact(str(out), artifact_path="bond_inventory")

# ─── ENTRYPOINT ──────────────────────────────────────────────────────────────
def main(days: int, max_workers: int = MAX_WORKERS):
    today = date.today()
    snapshots = [ today - relativedelta(days=i) for i in range(days) ]

    # one outer run for the whole backfill
    with mlflow.start_run(run_name="Backfill Inventory", nested=False):
        mlflow.log_param("days", days)
        # parallel
        with ThreadPoolExecutor(max_workers=max_workers) as exe:
            futures = { exe.submit(run_snapshot, d): d for d in snapshots }
            for f in as_completed(futures):
                d = futures[f]
                try:
                    f.result()
                except Exception as e:
                    print(f"⚠️ Snapshot {d} failed:", e)

if __name__ == "__main__":
    main(days=30)
# Out:
# 🏃 View run Inventory 2025-05-18 at: http://127.0.0.1:8768/#/experiments/1444/runs/385625b97dcf4f269b14987359c4620a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-15 at: http://127.0.0.1:8768/#/experiments/1444/runs/5509db57a5cd46a5893df19e395f7101
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-16 at: http://127.0.0.1:8768/#/experiments/1444/runs/32b88df1b5b340bba19bb3b85c64b642
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-19 at: http://127.0.0.1:8768/#/experiments/1444/runs/82018441660f4e15b84a88b267236f92
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-17 at: http://127.0.0.1:8768/#/experiments/1444/runs/de4a586907bf4fe28a913f7ded43d50c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-21 at: http://127.0.0.1:8768/#/experiments/1444/runs/f3812e197fee46aa9e26b85bb208173b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-20 at: http://127.0.0.1:8768/#/experiments/1444/runs/ebb9275f4c8b4314866e68eab83975e6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-22 at: http://127.0.0.1:8768/#/experiments/1444/runs/8418ba7b4d9748f598117f00066c7054
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-13 at: http://127.0.0.1:8768/#/experiments/1444/runs/a92f656c4a3a4b00a823633e9e51a745
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-14 at: http://127.0.0.1:8768/#/experiments/1444/runs/d024cb9365a04ca9aa45946ef11c6a4c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-09 at: http://127.0.0.1:8768/#/experiments/1444/runs/2a7e999a1c8c48c3a3c56484ea307365
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-11 at: http://127.0.0.1:8768/#/experiments/1444/runs/a7c41f4b3c68410e8623418dc9010b56
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-10 at: http://127.0.0.1:8768/#/experiments/1444/runs/03c33f33fd414261a1ae68e3267160e3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-07 at: http://127.0.0.1:8768/#/experiments/1444/runs/8202fcc139b54055a2b78b46bd76b137
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-12 at: http://127.0.0.1:8768/#/experiments/1444/runs/3196672837b3400cad185e04bb0e2850
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-08 at: http://127.0.0.1:8768/#/experiments/1444/runs/3cbdb50b11c6431ca568e2c3f5e55fbe
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-06 at: http://127.0.0.1:8768/#/experiments/1444/runs/b327b118cd0241c8a7e24bbe1801ec37
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-05 at: http://127.0.0.1:8768/#/experiments/1444/runs/33f0aba513ee4f63b148e705e3fdf0c7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-04 at: http://127.0.0.1:8768/#/experiments/1444/runs/88070ba82a354c37bea39abb5bae149c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-30 at: http://127.0.0.1:8768/#/experiments/1444/runs/ff1333984a1c48f38fa84c6dfb414dec
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-29 at: http://127.0.0.1:8768/#/experiments/1444/runs/ac94950ec87d43e29987cad73f80c304
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-02 at: http://127.0.0.1:8768/#/experiments/1444/runs/1806c8da28d4459fb90746f881d10056
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-01 at: http://127.0.0.1:8768/#/experiments/1444/runs/27701b6a119f4e3eb4994995562399c7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-05-03 at: http://127.0.0.1:8768/#/experiments/1444/runs/8c774ee9978d4f2d89f77329f1f7978d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-27 at: http://127.0.0.1:8768/#/experiments/1444/runs/085e75ca94de4bd19b132c47afed91e0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-28 at: http://127.0.0.1:8768/#/experiments/1444/runs/7cc83826ef754ac69ae54aea97092d7d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-26 at: http://127.0.0.1:8768/#/experiments/1444/runs/d15b2a77d7394b6fb6f7ad99e00541f4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-25 at: http://127.0.0.1:8768/#/experiments/1444/runs/87f7aee7c79c4704b440d37fc0be0fb4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-24 at: http://127.0.0.1:8768/#/experiments/1444/runs/fa12176850c24a849c649e075a5bba91
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Inventory 2025-04-23 at: http://127.0.0.1:8768/#/experiments/1444/runs/262021238c0240d78c6c79f32453b81b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
# 🏃 View run Backfill Inventory at: http://127.0.0.1:8768/#/experiments/1444/runs/d4a92b61256448c28f0558e701b5ecd7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1444
