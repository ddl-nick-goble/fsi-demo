# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import data.data_source as data_source
import time
import math
import uuid
from datetime import date
from dateutil.relativedelta import relativedelta
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor, as_completed
from config import env

import pandas as pd
import mlflow

# ─── CONFIG ───────────────────────────────────────────────────────────────────
experiment_name = f"Populate Tsy Inventory [{env}]"
mlflow.set_experiment(experiment_name)

BATCH_SIZE   = 1_000
MAX_WORKERS  = 8
ARTIFACT_DIR = "artifacts/results"

# ─── HELPERS ──────────────────────────────────────────────────────────────────
def find_mount_root(start: Path, target: str = "mnt") -> Path:
    p = start.resolve()
    while p.name != target and p.parent != p:
        p = p.parent
    if p.name != target:
        raise FileNotFoundError(f"‘{target}’ not found in {start}")
    return p

def sanitize_quantity(val):
    try:
        q = float(val)
        return 0.0 if (math.isnan(q) or math.isinf(q)) else round(q * 0.01, 2)
    except:
        return 0.0

def quote(val):
    if val is None:
        return "NULL"
    if isinstance(val, float) and (math.isnan(val) or math.isinf(val)):
        return "NULL"
    if hasattr(val, "tzinfo") and pd.isna(val):  # Timestamp check
        return "NULL"

    s = str(val)
    if s.strip().lower() in {"nan", "null", ""}:
        return "NULL"

    # escape single quotes by doubling them
    escaped = s.replace("'", "''")
    return "'{}'".format(escaped)

def chunks(seq, size):
    for i in range(0, len(seq), size):
        yield seq[i : i + size]

# ─── DATA & DB ────────────────────────────────────────────────────────────────
def fetch_active_bonds(ds, snapshot_date: date):
    sql = f"""
      SELECT *
        FROM treasury_auction_results
       WHERE security_type IN ('Note','Bill','Bond')
         AND issue_date   < '{snapshot_date}'
         AND maturity_date> '{snapshot_date}'
    """
    return ds.query(sql).to_pandas().to_dict(orient="records")

def upsert_inventory(ds, rows, snapshot_date: date):
    if not rows:
        mlflow.log_metric("rows_inserted", 0)
        return

    cols = [
      "inventory_date","cusip","quantity","security_type","security_term",
      "issue_date","maturity_date","int_rate","int_payment_frequency",
      "series","price_per100","auction_date"
    ]
    col_list = ", ".join(cols)
    set_list = ", ".join(f"{c}=EXCLUDED.{c}" for c in cols if c not in ("inventory_date","cusip"))

    for batch in chunks(rows, BATCH_SIZE):
        values = ["(" + ", ".join(quote(r.get(c)) for c in cols) + ")" for r in batch]
        template = """
        INSERT INTO bond_inventory ({col_list})
        VALUES
          {batch_values}
        ON CONFLICT (inventory_date, cusip) DO UPDATE SET
          {set_list};
        """
        sql = template.format(
          col_list    = col_list,
          batch_values= ",\n  ".join(values),
          set_list    = set_list
        )
        ds.query(sql)

# ─── WORKER ───────────────────────────────────────────────────────────────────
def run_snapshot(snapshot_date: date):
    # Give each thread its own DS/client
    ds = data_source.get_data_source()
    run_id = str(uuid.uuid4())
    with mlflow.start_run(run_name=f"Inventory {snapshot_date}", nested=True):
        mlflow.set_tag("snapshot_date", snapshot_date.isoformat())
        start = time.time()

        raw = fetch_active_bonds(ds, snapshot_date)
        mlflow.log_metric("rows_fetched", len(raw))

        # build inventory
        inv = []
        for r in raw:
            q = round(sanitize_quantity(r.get("comp_accepted")) / 1_000_000) * 5_000
            if q > 0 and r.get("cusip"):
                inv.append({
                    "inventory_date":  snapshot_date,
                    "cusip":           r["cusip"],
                    "quantity":        q,
                    "security_type":   r["security_type"],
                    "security_term":   r["security_term"],
                    "issue_date":      r["issue_date"],
                    "maturity_date":   r["maturity_date"],
                    "int_rate":        r["int_rate"],
                    "int_payment_frequency": r["int_payment_frequency"],
                    "series":          r["series"],
                    "price_per100":    r["price_per100"],
                    "auction_date":    r["auction_date"],
                })
        # dedupe
        seen = set()
        dedup = []
        for row in inv:
            key = (row["inventory_date"], row["cusip"])
            if key not in seen:
                seen.add(key)
                dedup.append(row)

        upsert_inventory(ds, dedup, snapshot_date)
        elapsed = time.time() - start
        mlflow.log_metric("rows_inserted", len(dedup))
        mlflow.log_metric("run_duration_sec", elapsed)

        # write out CSV and log artifact
        df = pd.DataFrame(dedup)
        mnt = find_mount_root(Path.cwd())
        out = mnt / ARTIFACT_DIR / f"bond_inventory_{snapshot_date}.csv"
        out.parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(out, index=False)
        mlflow.log_artifact(str(out), artifact_path="bond_inventory")

# ─── ENTRYPOINT ──────────────────────────────────────────────────────────────
def main(days: int, max_workers: int = MAX_WORKERS):
    today = date.today()
    snapshots = [ today - relativedelta(days=i) for i in range(days) ]

    # one outer run for the whole backfill
    with mlflow.start_run(run_name="Backfill Inventory", nested=False):
        mlflow.log_param("days", days)
        # parallel
        with ThreadPoolExecutor(max_workers=max_workers) as exe:
            futures = { exe.submit(run_snapshot, d): d for d in snapshots }
            for f in as_completed(futures):
                d = futures[f]
                try:
                    f.result()
                except Exception as e:
                    print(f"⚠️ Snapshot {d} failed:", e)

if __name__ == "__main__":
    main(days=365*30)
# Out:
# 🏃 View run Inventory 2024-12-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/98fb6f3ff44c47d69bd29aab3df185f9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/271995564e014fbb8b86ee706443e2ef
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/11b5c41760e44326a5933ff24af6d211
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/616aea7aa88d480493cb436d8f2408d9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/2cbccdaccde7491bac5f6a2b67009afc
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/50c104eeec5c402b9c814e601f8ae932
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/64320e494d3d454896d037e076badf9a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/0dc1327be7f644ad9d5346910a70a2d6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/f430f45b57a84f3f8b8c4782a30f834e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/6e7fae970ee64257b82ab91ee8d9fb40
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/e9c8e27e79e545a290a358bf51676ebf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/87e1e7c0aa384248822df8abbb472851
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/79fba123ff8e409f93f7c47e2e9c586a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/9fa7cdc78af04ffa8f1ba20325b28402
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/a4b4cd85673b47c2a9b67cdd8fca50e3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/112b91a5aae541a8abfdbd63e643b453
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/8dd138ea596d4b0581109c9f198207bb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/23306cfba20547f1887c03cf21ed52f6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/f6b29257378245b2990a79eec21c04b3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/c32dd188f7614e5e9792452c8158f9cf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/037b89e5d47041b687e996ca984d9f07
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/356bb094f0344231b187432074f73a69
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/6c3d459ad5494cf79b27f0f56e31da1e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/be4cbb1b250f4f0bbdf631b7966b06f0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/2819d87493c54265ae89fc7b6ca8b410
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/08f17b04d97d41fd9746fbb6ffd9d60a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/26e6e81629f34a1e8575558beda7d509
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/3fbc7f39ac024fb0912a064e6e56a0b1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/4b3928a631dd4cf3a5ce7a419eccf133
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/ebe3cb76adad475da25ecc0d637274a8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/db063b0ca0b541fa949642557a856fc8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/571adb478bef43c0aa610881a12444b4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/6b9a712287404d0db95c99211872c8ba
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/6efbd428d07941e2818e2a02e48f90b8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/ff5b8f31bac649adb79cd841e67f0c11
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/3a4fc54c7c6f418da55b851e650a58b5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/79f2a05ad8ee4347866d662dce20b3b7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/a96a016f41984e4b99a1882c6f327756
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/923ef8d93a3b41d98236afd0627c418b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/fa4341e052164f8d9b5f19de1a02d48d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/d48291fc384d4da38cf839c824623678
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/241b1fba234b418ca9fba69dc4124028
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/006043974e6945a4a08b04ef84cedfc6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/1eb580e9255746e5a9051e32ee01b454
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/d99e97b8ed404a99a4769cc5d946b579
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/e4d02abeb43f4eaaa39e33f58105cf3f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/54d05cb875af4fd9b99bb6bf3f0c1450
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/267b923273f142a6ab95197ce3b95ab5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/f313e22a40c5407bae6c5d4216fc5272
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/0509ba42977a4758b54236569d5b9ef0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/b0f7fe4f86244296b07cd8e0cec69f30
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/eb499b6ba8844520854d1351508929ea
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/c01352c7e34c475ab493eca174d03eb6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/6b4ba91d00324607b29c9441c08e5b1b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/52718395660a448a98bf0e603bf6cc0d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/556db6fbc1eb48b3af547d6296aac89f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/f813ceba84ca4b2d89f4e38cee12d4ce
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/44d16ff1e32740bd855a27f3dc9ab8b5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/2bad3d046aed4f268307f97df20d1ca2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/98d7a0f317bd450bae76987eed0a62b2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/7eec1e0141fc4bf4a9dc8aea61b9798b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/2e18690cc5b9404a8c13aac0630f826c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/c38d8c23b9904ed584a05ea292f956ce
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/8ee72681164e4b6493280c78a3650a2e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/9d6cbe2caebf4bd5be5e0c0506a7d917
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/d8abd938635f4b369efe1015e8354b8d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/7f0c2c8fcec446af8e23ab1d76d057c2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/cb8527e1dbae4dc0863004cf06dd08bf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-05-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/50d7bbfa73574835a21ab9dae114b9c8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-05-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/4bbbf5bc86b94a1eb45912168e4f51ba
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/68d2a7d57c8f4e0c80feb85624428c4a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/22ca1a2e83fa4772b329f132d7255d81
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/88d4337077a04607858e4b30230b78c1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/dad0eff3eb2d4bd6bbdb3a14e5a679d0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/f7f4834380824acda53973cd11490364
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/6d27f57c04004af4aed179b51ced133c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-31 at: http://127.0.0.1:8768/#/experiments/1463/runs/15e5cc888b494e3d869978ef117e3ce0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/3c55cb624cc64a598b93980d8b40df72
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/364d75282cfe425688dcc1cea4a071f1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandboxgetting data source for sandbox
# getting data source for sandbox
#
# 🏃 View run Inventory 2024-10-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/99286ddc8f1d41c08c6dec88fe3c93bf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/3e5a96f80d5442c78ae9b4c048d2b74d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/fb8758c8f2bc4908b9a57ada526f66cb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/7b7b1109c12343f4b74e8c9ed307409d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/30f49752f874460f8df61039ff10ddd4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/4b1dfed90b8441cbaa475ef02ee8d863
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/824f82df770345308da85a6600466c53
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/22898a7fedf442f8a04f8abc3f15c57f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/5d8e6a9c3ecb427293ddeb3d72c3d9cc
# 🏃 View run Inventory 2025-04-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/9436bcb02baa4a02874e76afd5f15d68
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/67b0473e6d654b4bb7238c92bb9ba6f5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/5b35b8697e4549709e6eb4798d8be3b6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/2306c416d64e44e58f6a7111d2a4865a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/3e80b8fda3ca49568ed763bc29927f82
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/64beebee13f041448a8a9f7aa21bae8c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/a9050cc72e61426b8fe469077f5d786b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/c62c7f97b95b4dd586ee8c8d0a6fb0c3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/05fa0b4b3b9c4ecda9886b0d28e14939
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/89f8e3ac2470487e9a7a6f2cf42f6d36
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/62e3dc0ff853416fbba1f109dae7ba06
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-04-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/1b2c7d7fbacd449b97f65b7c9d71efa0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/e94aa6c145df4a269c2068ce84b7a319
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-04-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/24c59c2bc6dd4b139b0d5994943ebb4e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/2142a1580e46404d83a7a3a9f0ff7302
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/5fcb1149bbbf4c6db073b276e8b8b853
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/5a392ec004334de4a8e9889e81dd1e7d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/d4412f0b2a784ab19351a14daa127b5a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/299296a11cb14043bc3785583ff088b3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/00e14ed008604fd1a77f78b6c712806e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/245e18c5ddd24960854e5910999a6477
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/fd067645a85d45dc8699dfe3931d2012
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/81e117e1ff7e43b2bede6f2a810a237f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/9e0afe2125a94f44a0d1b2feff7de757
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/b999f667d90842bfaa5a98f4f99a88c1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/f4fad6b0426841dfafac3da153ee8a0f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/8603f9fbab064b589b8448387c3a3f4e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/8c7a8436f58446a9a37bd6d2531065c9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/b98c31901b5e4b829d9577c8e8c55336
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-04-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/267cad1c68e64aae9240a98aec232534
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/22afc986465a46e5b89466a9016f3fcb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/eee4b12f08f541928c57188631bf76d1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/c4ac2754dde44ea7a463ec2b9bc66db0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-04-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/5ce970f120e1485697c362910e066732
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/bc33c715e34746a689219b8f5a0968ad
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-04-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/3af2656580dd438584f6e0515fe8a3df
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/8a35a8f31fba4ef68a388430228bb321
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/26114a9afa214c05a362abc2d0d188ec
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/b8d0c5843f684a24b060f4844b967765
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/64b8cb9e9f214e7db0ce6c3f14842047
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-04-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/98c8190b73e44db6963ce06a16511522
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-10-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/0740ca0b87e949bea4f3ecb8fdcc1e46
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/3722eb1a94ce427db5c0834df869c2a8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/1409d6ac6bd744c6b0246942e5bcb95c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/1018052bffa64fe495e686398468e862
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/e497a8e6b8014322b5b7ed8e50e12f4f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-10-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/89a9ed39348c44c19cf86ef2d0f48201
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-03-31 at: http://127.0.0.1:8768/#/experiments/1463/runs/276929025652429996d7289fbb6982af
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/a5438a268cd3482190a68acf05ab1807
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/06d6b3a3ca92416ea5243ac7c752da2a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/b3b72a084bf3454d9e7088eb7ecde799
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/8a5b3f4daa4c419c8bef5fdf99403296
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/2773fe35954d414ca1cf77590c3318d5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/33583df8c4c64e07bff545067e0b4a7d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/c4d451e5ee5e436b924051180f0920fe
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/50779c56267d4eb78ec021711d7d6a0a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/a8cd6d03fb924db291f98ed2668e8261
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-03-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/febd8606f01644589229c56aae747b68
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/60839af9080f4a50a19097d669cd404a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/4471904dc67448229be0a54ce4af0b40
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/61f355fe76e0417dab5aca6cfc9dc627
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox🏃 View run Inventory 2024-09-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/3bba30e8fd92456aa0792ece6ffb3ffe
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
#
# 🏃 View run Inventory 2025-03-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/11c85e701a48485b829e3c88f555f069
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/abd0a8aed0b040b486ca4b79a59ebf90
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/f0f3e964e6da41f684d08691928ce31c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/d43162c105c14c71a6e2ec2810a9001b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/ad45394e6f4e47c5bf97af527cfda948
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/c6c453fe2c5a473aa9387fbe65544d92
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/5a37225ff7984eed9f0aab521fd99cf7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/30a60a42cbbc4443bee82bc46f8ac9a0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/8b1a34b43b2947669c6c6dc60d29c013
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/b743999ccb2048509a46995951f0b6a0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/8b29e67c7bdd4e55a5f1dfa83870ef32
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/2a4367ae78b146e7a5f78ac2034bc5ff
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/4fc0d488b65d4977a7c6bff8cc980fb7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/dd154afc04494159b698361563e5adc6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/a07e373b4d48470da39e73e4f41b532d
# 🏃 View run Inventory 2024-09-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/55ebe500edd542598893a902fce3019d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/8ca2267796a84c1ab4ac8a32842b70ee
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox🏃 View run Inventory 2025-03-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/61962ab813294d6ea382ecbf5fabb7fe
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
#
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/b019e050169b4e49a830d6e9bbffae42
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-03-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/610a1f0f282d4cef8e065ba5f040445d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/029bf7a0104b42ea9544c7cb2eb3705f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/ba2cdee9aba848bf95935ed4848032ef
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/ed816020780343f985afc1f6a82268e0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/968caa872f464e24b20fb8dfcd158548
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/aefb8577441c4f93971807c161a9e2e3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/ab8ca416da5949b6850c51cacedf4317
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/499396bfb656434f85bdda4f32d60543
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/44b7a320812541e7a42ea0d32daacf90
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/05b7e55ce220445cb26d8c40dab99939
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/7b9b8c6bdf4b42a79954def005423062
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/ccbe25d759854fe6aaf736767fc01b8a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-03-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/4f898859c78c40ddacdd62535cb19345
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/073500992793432e8802ac5d13e6b5db
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/b5dc83f626d44099ab1ac142190596f6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/3d8f2a0c769c487fbc2535692e8be2d8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/8dba7f3542df4072a20c28082b6d0c8d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/5109e077b44b464ba86506f0ab8bcbf8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/8c2c03d4185c4a5087bb626a69a1288a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/2516cb90d6134d9f807146a4822c2d6f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/0efcffa89b664c2da529302b4208f512
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-03-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/651747821527408d961250ececd2babc
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/700f134c1bcb4a00a4264935fe1d5a2e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-09-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/527fcd133f4848998cf59313d20aeaf1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/ba02ae5b6eb340a098434326b3733086
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/bc175665b2de46c2b8e9b75c61bed0cd
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/00dae0101ae449a69ca92add83e4c788
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-09-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/5e09246d11684feebc3aa9b81e16fddf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/ef86bdd2bb2b4014b9bda506e855a285
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/191f37d3adcf40f88aa74af9cca7c2a9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-31 at: http://127.0.0.1:8768/#/experiments/1463/runs/d1ab06a504444d8cbff633c382d7e6a0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/e29c7022f1fd48aaa5a37090084af2a2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/50ec0048d9bc428496703e7c19b0008d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-08-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/d3fe367f71514e8099cc5543fdd16422
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/a28b07cfab14481aabf4f2aa06e5b2d9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/2555ebb1121d485ea8eab4644c9ad15d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-08-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/0e609ac2d83c486d9e5f880e4c75a132
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/b39bbf9fe40640e6b684a68c008dec23
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-08-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/c2ab097ace9a4e6399d0f80027e17946
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/12b01069ff724e7c8a2083d59f0be4ce
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/103c9f0bc370470f8e72b3c291080a0b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/ac8172f585c643b388ad7fba9c2d8de4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/4a7f2b50d1e9445485a18ac2588bc37c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/3a406c7f74184e42a1026987797b5bf8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/842ad02eebbf40438b3aaf7254c04456
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/ef3ad949c9494ca1962044935bac844a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/603f3489e5c3422dbed27acc463c7fae
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/5b8fdcc168934ff18bcc70543b2c18f6
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/225bc2ccca3442468d70d71267e102fb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/39f000b5779a452e8ff610457980798f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/cf44dc8c5f3043a790f0b944c6b64aa2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/df78628fa0d14781b2524b3b5afbfefb
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-08-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/70d546b09bdb45d2be421ce847f5fa01
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-08-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/c404c39434b4445c9800a3b57a6c06e4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/cc416407b0b04c33aee311f27e51f86c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2025-02-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/de14ad15bb844d53890f7f8fb38e363f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-08-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/8ffc58a98e8244528f196c27ace5f4f8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2025-02-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/9bd1581eb18d443f91c04691a7de23af
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# ...
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/a38f2419a43b4d42bc62c6602f593c8c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/9c5c9144209549218b2323127861cf2b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/d3018d0c58e84a60a617ae770a6ab80b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/29e79cc11a7b499fbe2a9fdd39ff2737
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/cf5e6b06bd3c4324b1d02982122fe04a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/1ddf7c9abcd1422899b4392108470784
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/8454cb00a04549319c76e38412a574ee
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/8a318b1f76b44e0c9ab50a6681d7ceb0
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-07-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/480d4ff4ee5b4e9a901a110f54be1d4b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/5fbc5f3ea72645fd9855625e1ddb00e3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox🏃 View run Inventory 2024-12-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/39491531b9fb4a22a06b7e5ad2577e2f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
#
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/5551b76df9d740a3ac15bd42ac6cc12b
# 🏃 View run Inventory 2024-12-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/a4710c9516984cf58f8f3e3a12f2a535
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/f4b4c52eacf540519731f2888ac76a5d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/3f280b3765194d4ba4b209d8a1f0fb12
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/8841b4a1c5034d3192b867059eba840b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/3b5496df1a7242af9c39911df8474218
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/a3dc319754b4433594f44573ff482720
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/f4bd1c60070f4f58b239df803d355b85
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/3bc9fac9fefd4708a348bab0ba45c917
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/776a173c048e42f7af7746fbd1b0899e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/c4c2cd75712b4a5c901f168f26928eb8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/df6bf49d8b364dfa823c9fd5dc025b4d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/8dd9e571e0e74a8cb1aa210efc4ef3ee
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/7f6d7e4c289841a0952a8b67a7c9c2b3
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/a8abfdc6db2847e19b6e87bd713514bc
# getting data source for sandbox
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/451eeb9f178e47a78e20b9f2e9e48bea
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/26b252693e03457c8066bdd0ba6c3a02
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-21 at: http://127.0.0.1:8768/#/experiments/1463/runs/fdad885ff65e4929b310841df846d135
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/5e8a2cc1456b4da6a0b5831e1786f2a5
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/5d649884b5cf46869c72eab5ad74f8af
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/0a4cceea9f9d4b1c875621f3f4e8cfec
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-22 at: http://127.0.0.1:8768/#/experiments/1463/runs/365ca7805c4e41f78644fdaf77ce0264
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/4ab47c53370e4173b2c333a046d70b2a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-19 at: http://127.0.0.1:8768/#/experiments/1463/runs/ddcd8e5d717a46898d4e60c241d37c92
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-20 at: http://127.0.0.1:8768/#/experiments/1463/runs/9ab72ad2a72b4bc8bbb7157ca9955c42
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-18 at: http://127.0.0.1:8768/#/experiments/1463/runs/bbb34b1744324254acecf8a6532e7842
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-17 at: http://127.0.0.1:8768/#/experiments/1463/runs/49c7ae2017f3417e971f7aab8718eded
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/6fa762f445e2470497283dc2ea789d3c
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-16 at: http://127.0.0.1:8768/#/experiments/1463/runs/a7cc1fa94f784bdc8871fd67a8a5b372
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-15 at: http://127.0.0.1:8768/#/experiments/1463/runs/60b4d62cdcee44c4a700da8ca0f32593
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/ebaec3157f83491f9d7887a8eb03b720
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/9ee74251875f46b08b93ca111fbb9fed
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/11465315889f433386d4e27ce71356d1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/1bfe664aac824607aa58b26ee5ff3d2a
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-14 at: http://127.0.0.1:8768/#/experiments/1463/runs/6ebb0dcdf95e43a595089782ff8cfdf4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/5bc41ad90eb948b191ec20a90fd40588
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-13 at: http://127.0.0.1:8768/#/experiments/1463/runs/8eed4560c0524768abfd6f5dd5b34096
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/f11c9bb4f6ac4439a4269baae5ff050d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-12 at: http://127.0.0.1:8768/#/experiments/1463/runs/f05528939b914545a7c19bf71c8b9d76
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/391e3e8840e74a84858e2fd46db09573
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-11 at: http://127.0.0.1:8768/#/experiments/1463/runs/bf28f652a2a34ddaba24133ea601a390
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-10 at: http://127.0.0.1:8768/#/experiments/1463/runs/0219aa42f4524c3c897aacc82114952f
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-09 at: http://127.0.0.1:8768/#/experiments/1463/runs/e581c8138cce4e58a258051abe8653c7
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/4ca8dfe1c1904a0ca0f3e44443977485
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-07 at: http://127.0.0.1:8768/#/experiments/1463/runs/dd263cdd00a74efdb9fdfb28c83517a4
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-08 at: http://127.0.0.1:8768/#/experiments/1463/runs/b780403c752e42969727439f1c366a5b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/bf7d5a02167840278f6bda4cc93b1ed8
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-12-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/1592f63cd3b541b3b7fb295acdb5d576
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-12-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/f358f89ecc3748e5ac71f526000c5a26
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/69845a0b499c4d9e8a32beae3bd32821
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-03 at: http://127.0.0.1:8768/#/experiments/1463/runs/0b2b92be23e84d848ff68f8db620dd4b
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-27 at: http://127.0.0.1:8768/#/experiments/1463/runs/58d0022d71ad4b50bacf26c446cafb28
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-06 at: http://127.0.0.1:8768/#/experiments/1463/runs/deb3fb40f5e149f2b27783f7c6873053
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-29 at: http://127.0.0.1:8768/#/experiments/1463/runs/9ccc9f7cb1644dd684ce28b499e0e8cf
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-05 at: http://127.0.0.1:8768/#/experiments/1463/runs/dff81688bb064a95a3a2fc831886d5cc
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-06-04 at: http://127.0.0.1:8768/#/experiments/1463/runs/c79714cfb331404aa669aa9477365794
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-28 at: http://127.0.0.1:8768/#/experiments/1463/runs/4ee3adb8b4cb4e00b32de9f9bbb6c59d
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-02 at: http://127.0.0.1:8768/#/experiments/1463/runs/b2ad24b0f5d24ca194b92b0e570e68f2
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-26 at: http://127.0.0.1:8768/#/experiments/1463/runs/8520fd80756f4362bd6c2e434ce7014e
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-06-01 at: http://127.0.0.1:8768/#/experiments/1463/runs/0cd3917d31dd4420a2b45e4ba69f26ef
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-05-31 at: http://127.0.0.1:8768/#/experiments/1463/runs/f7eb3110bbdd4467b9440b6f7bb91c91
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-05-30 at: http://127.0.0.1:8768/#/experiments/1463/runs/a2c04d63cd124125b9e1339860510755
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-24 at: http://127.0.0.1:8768/#/experiments/1463/runs/b93cc36b171347c9b9f61de4fb8ddc60
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# 🏃 View run Inventory 2024-11-25 at: http://127.0.0.1:8768/#/experiments/1463/runs/6bdadc3d22e94e528ed54e3b0a8a77a1
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
# getting data source for sandbox
# 🏃 View run Inventory 2024-11-23 at: http://127.0.0.1:8768/#/experiments/1463/runs/7d15a16238e4405daf2ea569346a4fe9
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1463
# getting data source for sandbox
