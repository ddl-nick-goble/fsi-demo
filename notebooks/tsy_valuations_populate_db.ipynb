# %%
## scripts/run_valuation.py
#!/usr/bin/env python3
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

import os
import time
import pandas as pd
import json
import numpy as np
import mlflow
from datetime import date, timedelta, datetime
from dateutil.relativedelta import relativedelta
from concurrent.futures import ThreadPoolExecutor, as_completed

from data.data_source import get_data_source
from data.treasury_curve import get_yield_curve, bump_curve, shocks
from models.pricing_models.bond_model import Bond

ds = get_data_source()

def run_valuation(asof_str):
    # 0) Parse / validate date
    asof = pd.to_datetime(asof_str)
    if pd.isna(asof):
        raise ValueError(f"Could not parse date '{asof_str}'")

    # 1) Pull inventory
    inv_sql = f"""
    SELECT DISTINCT ON(cusip)
        cusip,
        int_rate,
        issue_date,
        maturity_date,
        price_per100,
        quantity,
        int_payment_frequency
    FROM tsy_inventory
    WHERE inventory_date = '{asof.date()}'
    ORDER BY cusip, inventory_date DESC;
    """
    inv = ds.query(inv_sql).to_pandas()
    if inv.empty:
        print(f"No inventory on {asof.date()}")
        return

    # 2) Load base yield curve
    base_yc = get_yield_curve(asof, ds)
    if base_yc is None:
        print(f"No yield curve for {asof.date()}")
        return

    # 3) Build Bond objects
    bonds = [Bond(r.cusip, r.issue_date, r.maturity_date, r.int_rate, r.int_payment_frequency) for r in inv.itertuples()]

    # 4) Price base curve and sensitivities
    pvs_dirty, accrued_arr, pvs_clean, dv01s, krds_mat = Bond.price_batch_with_sensitivities(bonds, asof, base_yc)

    # 5) Prepare results DataFrame
    results = inv.copy().reset_index(drop=True)
    results['price_closedform']            = pvs_dirty
    results['clean_price_closedform']      = pvs_clean
    results['accrued_interest_closedform'] = accrued_arr
    results['dv01']                        = dv01s
    key_cols = ['krd1y','krd2y','krd3y','krd5y','krd7y','krd10y','krd20y','krd30y']
    for i, col in enumerate(key_cols):
        results[col] = krds_mat[:, i]

    # 6) Fetch PCA components
    pca_sql = f"""
    SELECT components
    FROM pca_results
    WHERE curve_type = 'US Treasury Par'
      AND curve_date = '{asof.date()}'
      AND n_components >= 3
    LIMIT 1;
    """
    pca_df = ds.query(pca_sql).to_pandas()
    if pca_df.empty:
        raise RuntimeError(f"No PCA results for {asof.date()}")
    raw = pca_df.loc[0, 'components']
    if isinstance(raw, (bytes, bytearray)):
        raw = raw.decode()
    comps = np.array(json.loads(raw), dtype=float)
    if comps.shape[0] < 3:
        raise RuntimeError("PCA did not return >=3 components.")
    pc1, pc2, pc3 = comps[0], comps[1], comps[2]

    # 7) Tenor grid
    tenors = np.array([0.25, 0.5, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0, 20.0, 30.0])
    if pc1.shape[0] != tenors.shape[0]:
        raise RuntimeError("Mismatch PCA length vs tenor grid.")

    # 8) PCA‐bumped curve helper
    def make_pca_bumped_curve(base_yc, tenors, loading, shift_bp):
        base_rates = base_yc(tenors)
        bumped = base_rates + loading * (shift_bp/100.0)
        def f(ttm_arr):
            flat = np.interp(ttm_arr.ravel(), tenors, bumped, left=bumped[0], right=bumped[-1])
            return flat.reshape(ttm_arr.shape)
        return f

    # 9) Compute PCA‑shocked dirty prices
    for col_label, (loading, bp) in {
        'price_closedform_pca1_u25bps': (pc1, +25),
        'price_closedform_pca1_d25bps': (pc1, -25),
        'price_closedform_pca2_u25bps': (pc2, +25),
        'price_closedform_pca2_d25bps': (pc2, -25),
        'price_closedform_pca3_u25bps': (pc3, +25),
        'price_closedform_pca3_d25bps': (pc3, -25),
        'price_closedform_pca1_u100bps': (pc1, +100),
        'price_closedform_pca1_d100bps': (pc1, -100),
        'price_closedform_pca2_u100bps': (pc2, +100),
        'price_closedform_pca2_d100bps': (pc2, -100),
        'price_closedform_pca3_u100bps': (pc3, +100),
        'price_closedform_pca3_d100bps': (pc3, -100),
        'price_closedform_pca1_u200bps': (pc1, +200),
        'price_closedform_pca1_d200bps': (pc1, -200),
        'price_closedform_pca2_u200bps': (pc2, +200),
        'price_closedform_pca2_d200bps': (pc2, -200),
        'price_closedform_pca3_u200bps': (pc3, +200),
        'price_closedform_pca3_d200bps': (pc3, -200)
    }.items():
        yc_bumped = make_pca_bumped_curve(base_yc, tenors, loading, bp)
        pvs_bump, _, _, _, _ = Bond.price_batch_with_sensitivities(bonds, asof, yc_bumped)
        results[col_label] = pvs_bump

    # 10) PCA DV01s (1bp shift)) PCA DV01s (1bp shift)
    yc_p1 = make_pca_bumped_curve(base_yc, tenors, pc1, +1)
    yc_p2 = make_pca_bumped_curve(base_yc, tenors, pc2, +1)
    yc_p3 = make_pca_bumped_curve(base_yc, tenors, pc3, +1)
    p1_1bp, _, _, _, _ = Bond.price_batch_with_sensitivities(bonds, asof, yc_p1)
    p2_1bp, _, _, _, _ = Bond.price_batch_with_sensitivities(bonds, asof, yc_p2)
    p3_1bp, _, _, _, _ = Bond.price_batch_with_sensitivities(bonds, asof, yc_p3)
    results['pca1_dv01'] = p1_1bp - results['price_closedform']
    results['pca2_dv01'] = p2_1bp - results['price_closedform']
    results['pca3_dv01'] = p3_1bp - results['price_closedform']

    # 11) Parallel shocks
    for lab in shocks:
        results[f'price_closedform_{lab}bps'] = 0.0
    for lab, bp in shocks.items():
        yc_b = bump_curve(base_yc, bp)
        pvs_b, _, _, _, _ = Bond.price_batch_with_sensitivities(bonds, asof, yc_b)
        results[f'price_closedform_{lab}bps'] = pvs_b

    # 12) Housekeeping + drop near‐maturity
    results['valuation_date'] = asof.date()
    results['time_to_maturity'] = (pd.to_datetime(results['maturity_date']) - asof).dt.days/365.25
    results['coupon'] = results['int_rate'].fillna(0.0)
    alive = results['time_to_maturity'] > 1e-4
    if not alive.all():
        dropped = results.loc[~alive, 'cusip'].tolist()
        print(f"⚠️ Dropping mature bonds: {dropped}")
    results = results[alive].reset_index(drop=True)

    # 13) Batch upsert data
    values_sql = []
    for r in results.itertuples(index=False):
        values_sql.append(
            f"('{r.cusip}','{r.valuation_date}',{r.price_per100},{r.coupon},"
            f"'{r.maturity_date}',{r.time_to_maturity},{r.dv01},"
            f"{r.krd1y},{r.krd2y},{r.krd3y},{r.krd5y},{r.krd7y},{r.krd10y},{r.krd20y},{r.krd30y},"
            f"{r.price_closedform},{r.price_closedform_u25bps},{r.price_closedform_d25bps},"
            f"{r.price_closedform_u100bps},{r.price_closedform_d100bps},"
            f"{r.price_closedform_u200bps},{r.price_closedform_d200bps},"
            # ← now include both “u” and “d” sides for each of the three PCs at 25bps
            f"{r.price_closedform_pca1_u25bps},{r.price_closedform_pca1_d25bps},"
            f"{r.price_closedform_pca2_u25bps},{r.price_closedform_pca2_d25bps},"
            f"{r.price_closedform_pca3_u25bps},{r.price_closedform_pca3_d25bps},"
            # ← same for 100bps bumps
            f"{r.price_closedform_pca1_u100bps},{r.price_closedform_pca1_d100bps},"
            f"{r.price_closedform_pca2_u100bps},{r.price_closedform_pca2_d100bps},"
            f"{r.price_closedform_pca3_u100bps},{r.price_closedform_pca3_d100bps},"
            # ← same for 200bps bumps
            f"{r.price_closedform_pca1_u200bps},{r.price_closedform_pca1_d200bps},"
            f"{r.price_closedform_pca2_u200bps},{r.price_closedform_pca2_d200bps},"
            f"{r.price_closedform_pca3_u200bps},{r.price_closedform_pca3_d200bps},"
            # ← then the 1bps PCA‐DV01s:
            f"{r.pca1_dv01},{r.pca2_dv01},{r.pca3_dv01},"
            # ← finally the remaining fields
            f"{r.quantity},{r.clean_price_closedform},{r.accrued_interest_closedform})"
        )
    vals = ",".join(values_sql)

    upsert_sql = f"""
    INSERT INTO tsy_valuations (
      cusip,
      valuation_date,
      entry_price,
      coupon,
      maturity_date,
      time_to_maturity,
      dv01,
      krd1y,
      krd2y,
      krd3y,
      krd5y,
      krd7y,
      krd10y,
      krd20y,
      krd30y,
      price_closedform,
      price_closedform_u25bps,
      price_closedform_d25bps,
      price_closedform_u100bps,
      price_closedform_d100bps,
      price_closedform_u200bps,
      price_closedform_d200bps,
      price_closedform_pca1_u25bps,
      price_closedform_pca1_d25bps,
      price_closedform_pca2_u25bps,
      price_closedform_pca2_d25bps,
      price_closedform_pca3_u25bps,
      price_closedform_pca3_d25bps,
      price_closedform_pca1_u100bps,
      price_closedform_pca1_d100bps,
      price_closedform_pca2_u100bps,
      price_closedform_pca2_d100bps,
      price_closedform_pca3_u100bps,
      price_closedform_pca3_d100bps,
      price_closedform_pca1_u200bps,
      price_closedform_pca1_d200bps,
      price_closedform_pca2_u200bps,
      price_closedform_pca2_d200bps,
      price_closedform_pca3_u200bps,
      price_closedform_pca3_d200bps,
      pca1_dv01,
      pca2_dv01,
      pca3_dv01,
      quantity,
      clean_price_closedform,
      accrued_interest_closedform
    ) VALUES {vals}
    ON CONFLICT(cusip,valuation_date) DO UPDATE SET
      entry_price=EXCLUDED.entry_price,
      coupon=EXCLUDED.coupon,
      maturity_date=EXCLUDED.maturity_date,
      time_to_maturity=EXCLUDED.time_to_maturity,
      dv01=EXCLUDED.dv01,
      krd1y=EXCLUDED.krd1y,
      krd2y=EXCLUDED.krd2y,
      krd3y=EXCLUDED.krd3y,
      krd5y=EXCLUDED.krd5y,
      krd7y=EXCLUDED.krd7y,
      krd10y=EXCLUDED.krd10y,
      krd20y=EXCLUDED.krd20y,
      krd30y=EXCLUDED.krd30y,
      price_closedform=EXCLUDED.price_closedform,
      price_closedform_u25bps=EXCLUDED.price_closedform_u25bps,
      price_closedform_d25bps=EXCLUDED.price_closedform_d25bps,
      price_closedform_u100bps=EXCLUDED.price_closedform_u100bps,
      price_closedform_d100bps=EXCLUDED.price_closedform_d100bps,
      price_closedform_u200bps=EXCLUDED.price_closedform_u200bps,
      price_closedform_d200bps=EXCLUDED.price_closedform_d200bps,
      price_closedform_pca1_u25bps=EXCLUDED.price_closedform_pca1_u25bps,
      price_closedform_pca1_d25bps=EXCLUDED.price_closedform_pca1_d25bps,
      price_closedform_pca2_u25bps=EXCLUDED.price_closedform_pca2_u25bps,
      price_closedform_pca2_d25bps=EXCLUDED.price_closedform_pca2_d25bps,
      price_closedform_pca3_u25bps=EXCLUDED.price_closedform_pca3_u25bps,
      price_closedform_pca3_d25bps=EXCLUDED.price_closedform_pca3_d25bps,
      price_closedform_pca1_u100bps=EXCLUDED.price_closedform_pca1_u100bps,
      price_closedform_pca1_d100bps=EXCLUDED.price_closedform_pca1_d100bps,
      price_closedform_pca2_u100bps=EXCLUDED.price_closedform_pca2_u100bps,
      price_closedform_pca2_d100bps=EXCLUDED.price_closedform_pca2_d100bps,
      price_closedform_pca3_u100bps=EXCLUDED.price_closedform_pca3_u100bps,
      price_closedform_pca3_d100bps=EXCLUDED.price_closedform_pca3_d100bps,
      price_closedform_pca1_u200bps=EXCLUDED.price_closedform_pca1_u200bps,
      price_closedform_pca1_d200bps=EXCLUDED.price_closedform_pca1_d200bps,
      price_closedform_pca2_u200bps=EXCLUDED.price_closedform_pca2_u200bps,
      price_closedform_pca2_d200bps=EXCLUDED.price_closedform_pca2_d200bps,
      price_closedform_pca3_u200bps=EXCLUDED.price_closedform_pca3_u200bps,
      price_closedform_pca3_d200bps=EXCLUDED.price_closedform_pca3_d200bps,
      pca1_dv01=EXCLUDED.pca1_dv01,
      pca2_dv01=EXCLUDED.pca2_dv01,
      pca3_dv01=EXCLUDED.pca3_dv01,
      quantity=EXCLUDED.quantity,
      clean_price_closedform=EXCLUDED.clean_price_closedform,
      accrued_interest_closedform=EXCLUDED.accrued_interest_closedform,
      updated_at=CURRENT_TIMESTAMP;
    """
    ds.query(upsert_sql)
    print(f"✅ Valued {len(bonds)} bonds on {asof.date()}.")



def populate(
    days: int,
    max_workers: int = 4,
    years_back: int = 0
):
    """
    Backfill bond valuations for the last `days` days (up to today), not before 2010‑01‑01.
    """
    end_date = date.today()
    start_date = end_date - relativedelta(days=days, years=years_back)
    min_date = date(2010, 1, 1)
    if start_date < min_date:
        start_date = min_date

    all_dates = pd.date_range(start=start_date, end=end_date, freq='D').date
    print(f"Populating {len(all_dates)} days from {start_date} to {end_date}...")

    with mlflow.start_run() as run:
        mlflow.log_param("days_requested", days)
        mlflow.log_param("start_date", str(start_date))
        mlflow.log_param("end_date", str(end_date))

        errors = []
        def task(d):
            try:
                run_valuation(str(d))
            except Exception as e:
                return (d, str(e))
            return None

        with ThreadPoolExecutor(max_workers=max_workers) as exe:
            futures = {exe.submit(task, d): d for d in all_dates}
            for fut in as_completed(futures):
                res = fut.result()
                if res is not None:
                    errors.append(res)

        mlflow.log_metric("dates_processed", len(all_dates) - len(errors))
        mlflow.log_metric("errors", len(errors))

        if errors:
            print(f"⚠️  {len(errors)} dates failed:")
            for d, msg in errors:
                print(f"  • {d}: {msg}")

    print("✅ Backfill complete.")


# ─── MAIN ───────────────────────────────────────────────────────────────────
if __name__ == '__main__':
    if len(sys.argv) > 1 and sys.argv[1].isdigit():
        d = int(sys.argv[1])
    else:
        d = 365
    populate(days=d, years_back=1)
# Out:
# getting data source for sandbox
# Populating 731 days from 2023-06-02 to 2025-06-01...
# ✅ Valued 264 bonds on 2023-06-05.
# ✅ Valued 264 bonds on 2023-06-02.
# ✅ Valued 264 bonds on 2023-06-06.
# ✅ Valued 264 bonds on 2023-06-07.
# ✅ Valued 264 bonds on 2023-06-08.
# ✅ Valued 264 bonds on 2023-06-09.
# ✅ Valued 264 bonds on 2023-06-12.
# ✅ Valued 264 bonds on 2023-06-13.
# ✅ Valued 264 bonds on 2023-06-14.
# ✅ Valued 263 bonds on 2023-06-15.
# ✅ Valued 265 bonds on 2023-06-16.
# ✅ Valued 265 bonds on 2023-06-20.
# ✅ Valued 265 bonds on 2023-06-21.
# ✅ Valued 265 bonds on 2023-06-22.
# ✅ Valued 265 bonds on 2023-06-23.
# ✅ Valued 264 bonds on 2023-06-28.
# ✅ Valued 265 bonds on 2023-06-27.
# ✅ Valued 265 bonds on 2023-06-26.
# ✅ Valued 264 bonds on 2023-06-29.
# ✅ Valued 264 bonds on 2023-07-03.
# ✅ Valued 264 bonds on 2023-06-30.
# ✅ Valued 264 bonds on 2023-07-05.
# ✅ Valued 264 bonds on 2023-07-06.
# ✅ Valued 264 bonds on 2023-07-07.
# ✅ Valued 264 bonds on 2023-07-10.
# ✅ Valued 264 bonds on 2023-07-11.
# ✅ Valued 264 bonds on 2023-07-12.
# ✅ Valued 264 bonds on 2023-07-13.
# ✅ Valued 265 bonds on 2023-07-14.
# ✅ Valued 264 bonds on 2023-07-17.
# ✅ Valued 265 bonds on 2023-07-18.
# ✅ Valued 265 bonds on 2023-07-19.
# ✅ Valued 265 bonds on 2023-07-20.
# ✅ Valued 265 bonds on 2023-07-21.
# ✅ Valued 265 bonds on 2023-07-24.
# ✅ Valued 264 bonds on 2023-07-25.
# ✅ Valued 264 bonds on 2023-07-26.
# ✅ Valued 264 bonds on 2023-07-27.
# ✅ Valued 264 bonds on 2023-07-28.
# ✅ Valued 261 bonds on 2023-07-31.
# ✅ Valued 264 bonds on 2023-08-01.
# ✅ Valued 264 bonds on 2023-08-02.
# ✅ Valued 264 bonds on 2023-08-03.
# ✅ Valued 264 bonds on 2023-08-04.
# ✅ Valued 264 bonds on 2023-08-07.
# ✅ Valued 264 bonds on 2023-08-10.✅ Valued 264 bonds on 2023-08-09.
#
# ✅ Valued 264 bonds on 2023-08-08.
# ✅ Valued 265 bonds on 2023-08-11.
# ✅ Valued 265 bonds on 2023-08-14.
# ✅ Valued 264 bonds on 2023-08-15.
# ✅ Valued 267 bonds on 2023-08-17.
# ✅ Valued 267 bonds on 2023-08-16.
# ✅ Valued 267 bonds on 2023-08-18.
# ✅ Valued 267 bonds on 2023-08-21.
# ✅ Valued 266 bonds on 2023-08-22.
# ✅ Valued 266 bonds on 2023-08-23.
# ✅ Valued 266 bonds on 2023-08-24.
# ✅ Valued 266 bonds on 2023-08-25.
# ✅ Valued 266 bonds on 2023-08-28.
# ✅ Valued 263 bonds on 2023-08-29.
# ✅ Valued 263 bonds on 2023-08-30.
# ✅ Valued 263 bonds on 2023-08-31.
# ✅ Valued 267 bonds on 2023-09-01.
# ✅ Valued 267 bonds on 2023-09-05.
# ✅ Valued 267 bonds on 2023-09-06.
# ✅ Valued 267 bonds on 2023-09-07.
# ✅ Valued 268 bonds on 2023-09-08.
# ✅ Valued 268 bonds on 2023-09-12.
# ✅ Valued 268 bonds on 2023-09-13.
# ✅ Valued 268 bonds on 2023-09-11.
# ✅ Valued 268 bonds on 2023-09-14.
# ✅ Valued 267 bonds on 2023-09-15.
# ✅ Valued 268 bonds on 2023-09-18.
# ✅ Valued 268 bonds on 2023-09-20.
# ✅ Valued 268 bonds on 2023-09-19.
# ✅ Valued 267 bonds on 2023-09-21.✅ Valued 267 bonds on 2023-09-22.
#
# ✅ Valued 267 bonds on 2023-09-25.
# ✅ Valued 267 bonds on 2023-09-26.
# ✅ Valued 267 bonds on 2023-09-27.
# ✅ Valued 267 bonds on 2023-09-28.
# ✅ Valued 267 bonds on 2023-09-29.
# ✅ Valued 268 bonds on 2023-10-03.
# ✅ Valued 265 bonds on 2023-10-02.
# ✅ Valued 268 bonds on 2023-10-04.
# ✅ Valued 268 bonds on 2023-10-05.
# ✅ Valued 269 bonds on 2023-10-06.
# ✅ Valued 269 bonds on 2023-10-10.
# ✅ Valued 269 bonds on 2023-10-11.✅ Valued 269 bonds on 2023-10-12.
#
# ✅ Valued 269 bonds on 2023-10-13.
# ✅ Valued 268 bonds on 2023-10-16.
# ✅ Valued 268 bonds on 2023-10-18.
# ✅ Valued 269 bonds on 2023-10-17.
# ✅ Valued 268 bonds on 2023-10-19.
# ✅ Valued 268 bonds on 2023-10-23.
# ✅ Valued 268 bonds on 2023-10-20.
# ✅ Valued 268 bonds on 2023-10-25.
# ✅ Valued 268 bonds on 2023-10-24.
# ✅ Valued 268 bonds on 2023-10-27.
# ✅ Valued 268 bonds on 2023-10-26.
# ✅ Valued 265 bonds on 2023-10-31.
# ✅ Valued 265 bonds on 2023-10-30.
# ✅ Valued 268 bonds on 2023-11-01.
# ✅ Valued 268 bonds on 2023-11-02.
# ✅ Valued 269 bonds on 2023-11-03.
# ✅ Valued 269 bonds on 2023-11-06.
# ✅ Valued 269 bonds on 2023-11-07.
# ✅ Valued 269 bonds on 2023-11-08.
# ✅ Valued 269 bonds on 2023-11-09.
# ✅ Valued 269 bonds on 2023-11-10.
# ✅ Valued 269 bonds on 2023-11-13.
# ✅ Valued 269 bonds on 2023-11-14.
# ✅ Valued 268 bonds on 2023-11-15.
# ✅ Valued 270 bonds on 2023-11-16.
# ✅ Valued 270 bonds on 2023-11-17.
# ✅ Valued 270 bonds on 2023-11-21.
# ✅ Valued 270 bonds on 2023-11-20.
# ✅ Valued 270 bonds on 2023-11-22.
# ✅ Valued 270 bonds on 2023-11-24.
# ✅ Valued 270 bonds on 2023-11-27.
# ✅ Valued 270 bonds on 2023-11-28.
# ✅ Valued 270 bonds on 2023-11-30.
# ✅ Valued 270 bonds on 2023-11-29.
# ✅ Valued 273 bonds on 2023-12-01.
# ✅ Valued 273 bonds on 2023-12-04.
# ✅ Valued 273 bonds on 2023-12-05.
# ✅ Valued 273 bonds on 2023-12-06.
# ✅ Valued 273 bonds on 2023-12-07.
# ✅ Valued 273 bonds on 2023-12-08.
# ✅ Valued 273 bonds on 2023-12-11.
# ✅ Valued 273 bonds on 2023-12-12.
# ✅ Valued 272 bonds on 2023-12-13.
# ✅ Valued 272 bonds on 2023-12-14.
# ✅ Valued 271 bonds on 2023-12-15.
# ✅ Valued 272 bonds on 2023-12-18.
# ✅ Valued 272 bonds on 2023-12-19.
# ✅ Valued 272 bonds on 2023-12-20.
# ✅ Valued 272 bonds on 2023-12-21.
# ✅ Valued 272 bonds on 2023-12-22.
# ✅ Valued 272 bonds on 2023-12-26.
# ✅ Valued 272 bonds on 2023-12-28.
# ✅ Valued 272 bonds on 2023-12-27.
# ✅ Valued 273 bonds on 2023-12-29.
# ✅ Valued 270 bonds on 2024-01-02.
# ✅ Valued 273 bonds on 2024-01-03.
# ✅ Valued 273 bonds on 2024-01-04.
# ✅ Valued 273 bonds on 2024-01-05.
# ✅ Valued 273 bonds on 2024-01-08.
# ✅ Valued 273 bonds on 2024-01-09.
# ✅ Valued 273 bonds on 2024-01-10.
# ✅ Valued 272 bonds on 2024-01-11.
# ✅ Valued 272 bonds on 2024-01-12.
# ✅ Valued 272 bonds on 2024-01-17.
# ✅ Valued 272 bonds on 2024-01-18.
# ✅ Valued 271 bonds on 2024-01-16.
# ✅ Valued 272 bonds on 2024-01-19.
# ✅ Valued 272 bonds on 2024-01-23.
# ✅ Valued 272 bonds on 2024-01-22.
# ✅ Valued 272 bonds on 2024-01-24.✅ Valued 272 bonds on 2024-01-25.
#
# ✅ Valued 273 bonds on 2024-01-26.
# ✅ Valued 273 bonds on 2024-01-29.
# ✅ Valued 273 bonds on 2024-01-30.
# ✅ Valued 270 bonds on 2024-01-31.
# ✅ Valued 273 bonds on 2024-02-01.
# ✅ Valued 273 bonds on 2024-02-02.
# ✅ Valued 273 bonds on 2024-02-05.
# ✅ Valued 273 bonds on 2024-02-06.
# ✅ Valued 273 bonds on 2024-02-07.
# ✅ Valued 272 bonds on 2024-02-08.
# ✅ Valued 272 bonds on 2024-02-09.
# ✅ Valued 272 bonds on 2024-02-12.
# ✅ Valued 272 bonds on 2024-02-14.
# ✅ Valued 272 bonds on 2024-02-13.
# ✅ Valued 271 bonds on 2024-02-15.
# ✅ Valued 274 bonds on 2024-02-16.
# ✅ Valued 274 bonds on 2024-02-20.
# ✅ Valued 274 bonds on 2024-02-21.
# ✅ Valued 274 bonds on 2024-02-22.
# ✅ Valued 275 bonds on 2024-02-23.
# ✅ Valued 275 bonds on 2024-02-26.
# ✅ Valued 275 bonds on 2024-02-27.
# ✅ Valued 275 bonds on 2024-02-28.
# ✅ Valued 275 bonds on 2024-02-29.
# ✅ Valued 276 bonds on 2024-03-01.
# ✅ Valued 276 bonds on 2024-03-04.
# ✅ Valued 275 bonds on 2024-03-05.
# ✅ Valued 275 bonds on 2024-03-06.
# ✅ Valued 275 bonds on 2024-03-07.
# ✅ Valued 275 bonds on 2024-03-08.
# ✅ Valued 275 bonds on 2024-03-11.
# ✅ Valued 275 bonds on 2024-03-12.
# ✅ Valued 275 bonds on 2024-03-13.
# ✅ Valued 275 bonds on 2024-03-14.
# ✅ Valued 274 bonds on 2024-03-15.
# ✅ Valued 275 bonds on 2024-03-18.
# ✅ Valued 275 bonds on 2024-03-19.
# ✅ Valued 275 bonds on 2024-03-20.
# ✅ Valued 275 bonds on 2024-03-21.
# ✅ Valued 276 bonds on 2024-03-22.
# ✅ Valued 276 bonds on 2024-03-25.
# ✅ Valued 276 bonds on 2024-03-27.
# ✅ Valued 276 bonds on 2024-03-26.
# ✅ Valued 276 bonds on 2024-03-28.
# ✅ Valued 273 bonds on 2024-04-01.
# ✅ Valued 276 bonds on 2024-04-02.
# ✅ Valued 275 bonds on 2024-04-03.
# ✅ Valued 275 bonds on 2024-04-04.
# ✅ Valued 275 bonds on 2024-04-05.
# ✅ Valued 275 bonds on 2024-04-08.
# ✅ Valued 275 bonds on 2024-04-10.
# ✅ Valued 275 bonds on 2024-04-09.
# ✅ Valued 275 bonds on 2024-04-11.
# ✅ Valued 275 bonds on 2024-04-12.
# ✅ Valued 274 bonds on 2024-04-15.
# ✅ Valued 275 bonds on 2024-04-18.
# ✅ Valued 275 bonds on 2024-04-16.
# ✅ Valued 275 bonds on 2024-04-17.
# ✅ Valued 276 bonds on 2024-04-19.
# ✅ Valued 276 bonds on 2024-04-22.
# ✅ Valued 276 bonds on 2024-04-23.
# ✅ Valued 276 bonds on 2024-04-24.
# ✅ Valued 276 bonds on 2024-04-25.
# ✅ Valued 276 bonds on 2024-04-26.
# ✅ Valued 276 bonds on 2024-04-29.
# ✅ Valued 276 bonds on 2024-04-30.
# ✅ Valued 275 bonds on 2024-05-01.
# ✅ Valued 275 bonds on 2024-05-02.
# ✅ Valued 275 bonds on 2024-05-03.
# ✅ Valued 275 bonds on 2024-05-06.
# ✅ Valued 275 bonds on 2024-05-08.
# ✅ Valued 275 bonds on 2024-05-07.
# ✅ Valued 275 bonds on 2024-05-09.
# ✅ Valued 275 bonds on 2024-05-10.
# ✅ Valued 275 bonds on 2024-05-13.
# ✅ Valued 274 bonds on 2024-05-15.
# ✅ Valued 275 bonds on 2024-05-14.
# ✅ Valued 277 bonds on 2024-05-16.
# ✅ Valued 278 bonds on 2024-05-17.
# ✅ Valued 278 bonds on 2024-05-20.
# ✅ Valued 278 bonds on 2024-05-21.
# ✅ Valued 278 bonds on 2024-05-22.
# ✅ Valued 278 bonds on 2024-05-23.
# ✅ Valued 278 bonds on 2024-05-24.
# ✅ Valued 278 bonds on 2024-05-28.
# ✅ Valued 274 bonds on 2024-05-30.
# ✅ Valued 277 bonds on 2024-05-29.
# ✅ Valued 274 bonds on 2024-05-31.
# ✅ Valued 278 bonds on 2024-06-04.
# ✅ Valued 278 bonds on 2024-06-03.
# ✅ Valued 278 bonds on 2024-06-05.
# ✅ Valued 278 bonds on 2024-06-06.
# ✅ Valued 278 bonds on 2024-06-10.
# ✅ Valued 278 bonds on 2024-06-07.
# ✅ Valued 278 bonds on 2024-06-12.
# ✅ Valued 278 bonds on 2024-06-11.
# ✅ Valued 279 bonds on 2024-06-14.
# ✅ Valued 278 bonds on 2024-06-13.
# ✅ Valued 279 bonds on 2024-06-18.
# ✅ Valued 278 bonds on 2024-06-17.
# ✅ Valued 279 bonds on 2024-06-20.
# ✅ Valued 279 bonds on 2024-06-21.
# ✅ Valued 278 bonds on 2024-06-26.
# ✅ Valued 279 bonds on 2024-06-25.
# ✅ Valued 279 bonds on 2024-06-24.
# ✅ Valued 278 bonds on 2024-06-27.
# ✅ Valued 275 bonds on 2024-07-01.
# ✅ Valued 278 bonds on 2024-06-28.
# ✅ Valued 278 bonds on 2024-07-03.
# ✅ Valued 278 bonds on 2024-07-02.
# ✅ Valued 278 bonds on 2024-07-05.
# ✅ Valued 278 bonds on 2024-07-08.
# ✅ Valued 278 bonds on 2024-07-09.
# ✅ Valued 278 bonds on 2024-07-10.
# ✅ Valued 278 bonds on 2024-07-11.
# ✅ Valued 279 bonds on 2024-07-12.
# ✅ Valued 278 bonds on 2024-07-15.
# ✅ Valued 279 bonds on 2024-07-17.
# ✅ Valued 279 bonds on 2024-07-16.
# ✅ Valued 279 bonds on 2024-07-18.
# ✅ Valued 279 bonds on 2024-07-19.
# ✅ Valued 279 bonds on 2024-07-22.
# ✅ Valued 278 bonds on 2024-07-24.
# ✅ Valued 278 bonds on 2024-07-23.
# ✅ Valued 278 bonds on 2024-07-25.
# ✅ Valued 278 bonds on 2024-07-26.
# ✅ Valued 278 bonds on 2024-07-29.
# ✅ Valued 278 bonds on 2024-07-30.
# ✅ Valued 275 bonds on 2024-07-31.
# ✅ Valued 278 bonds on 2024-08-01.
# ✅ Valued 278 bonds on 2024-08-02.
# ✅ Valued 278 bonds on 2024-08-05.
# ✅ Valued 278 bonds on 2024-08-06.
# ✅ Valued 278 bonds on 2024-08-07.
# ✅ Valued 278 bonds on 2024-08-08.
# ✅ Valued 279 bonds on 2024-08-09.
# ✅ Valued 279 bonds on 2024-08-12.
# ✅ Valued 279 bonds on 2024-08-13.
# ✅ Valued 279 bonds on 2024-08-14.
# ✅ Valued 277 bonds on 2024-08-15.
# ✅ Valued 280 bonds on 2024-08-16.
# ✅ Valued 280 bonds on 2024-08-19.
# ✅ Valued 279 bonds on 2024-08-20.
# ✅ Valued 279 bonds on 2024-08-21.
# ✅ Valued 279 bonds on 2024-08-22.
# ✅ Valued 279 bonds on 2024-08-23.
# ✅ Valued 279 bonds on 2024-08-26.
# ✅ Valued 279 bonds on 2024-08-27.
# ✅ Valued 276 bonds on 2024-08-28.
# ✅ Valued 276 bonds on 2024-08-29.
# ✅ Valued 276 bonds on 2024-08-30.
# ✅ Valued 280 bonds on 2024-09-04.
# ✅ Valued 281 bonds on 2024-09-06.
# ✅ Valued 276 bonds on 2024-09-03.
# ✅ Valued 280 bonds on 2024-09-05.
# ✅ Valued 281 bonds on 2024-09-10.
# ✅ Valued 281 bonds on 2024-09-09.
# ✅ Valued 281 bonds on 2024-09-12.
# ✅ Valued 281 bonds on 2024-09-11.
# ✅ Valued 281 bonds on 2024-09-13.
# ✅ Valued 280 bonds on 2024-09-16.
# ✅ Valued 281 bonds on 2024-09-17.
# ✅ Valued 281 bonds on 2024-09-18.
# ✅ Valued 281 bonds on 2024-09-19.
# ✅ Valued 280 bonds on 2024-09-20.
# ✅ Valued 280 bonds on 2024-09-23.
# ✅ Valued 280 bonds on 2024-09-24.
# ✅ Valued 280 bonds on 2024-09-25.
# ✅ Valued 280 bonds on 2024-09-26.
# ✅ Valued 280 bonds on 2024-09-27.
# ✅ Valued 280 bonds on 2024-09-30.
# ✅ Valued 280 bonds on 2024-10-01.
# ✅ Valued 280 bonds on 2024-10-02.
# ✅ Valued 280 bonds on 2024-10-03.
# ✅ Valued 281 bonds on 2024-10-04.
# ✅ Valued 281 bonds on 2024-10-07.
# ✅ Valued 281 bonds on 2024-10-08.
# ✅ Valued 281 bonds on 2024-10-09.
# ✅ Valued 281 bonds on 2024-10-10.
# ✅ Valued 281 bonds on 2024-10-11.
# ✅ Valued 280 bonds on 2024-10-15.
# ✅ Valued 281 bonds on 2024-10-16.
# ✅ Valued 280 bonds on 2024-10-17.
# ✅ Valued 280 bonds on 2024-10-18.
# ✅ Valued 280 bonds on 2024-10-22.✅ Valued 280 bonds on 2024-10-21.
#
# ✅ Valued 280 bonds on 2024-10-23.
# ✅ Valued 280 bonds on 2024-10-24.
# ✅ Valued 280 bonds on 2024-10-25.
# ✅ Valued 280 bonds on 2024-10-28.
# ✅ Valued 277 bonds on 2024-10-30.✅ Valued 280 bonds on 2024-10-29.
#
# ✅ Valued 277 bonds on 2024-10-31.
# ✅ Valued 281 bonds on 2024-11-01.
# ✅ Valued 281 bonds on 2024-11-05.
# ✅ Valued 281 bonds on 2024-11-04.
# ✅ Valued 281 bonds on 2024-11-07.
# ✅ Valued 281 bonds on 2024-11-06.
# ✅ Valued 281 bonds on 2024-11-08.
# ✅ Valued 281 bonds on 2024-11-12.
# ✅ Valued 281 bonds on 2024-11-13.
# ✅ Valued 281 bonds on 2024-11-14.✅ Valued 278 bonds on 2024-11-15.
#
# ✅ Valued 281 bonds on 2024-11-19.
# ✅ Valued 281 bonds on 2024-11-18.
# ✅ Valued 281 bonds on 2024-11-21.
# ✅ Valued 281 bonds on 2024-11-20.
# ✅ Valued 281 bonds on 2024-11-22.
# ✅ Valued 281 bonds on 2024-11-25.
# ✅ Valued 281 bonds on 2024-11-26.
# ✅ Valued 281 bonds on 2024-11-27.
# ✅ Valued 281 bonds on 2024-11-29.
# ✅ Valued 279 bonds on 2024-12-02.
# ✅ Valued 283 bonds on 2024-12-04.
# ✅ Valued 283 bonds on 2024-12-03.
# ✅ Valued 283 bonds on 2024-12-05.
# ✅ Valued 283 bonds on 2024-12-06.
# ✅ Valued 283 bonds on 2024-12-11.
# ✅ Valued 283 bonds on 2024-12-10.
# ✅ Valued 283 bonds on 2024-12-09.
# ✅ Valued 282 bonds on 2024-12-12.
# ✅ Valued 282 bonds on 2024-12-13.
# ✅ Valued 281 bonds on 2024-12-16.
# ✅ Valued 282 bonds on 2024-12-17.✅ Valued 282 bonds on 2024-12-18.
#
# ✅ Valued 282 bonds on 2024-12-20.
# ✅ Valued 282 bonds on 2024-12-19.
# ✅ Valued 282 bonds on 2024-12-24.
# ✅ Valued 282 bonds on 2024-12-23.
# ✅ Valued 282 bonds on 2024-12-26.
# ✅ Valued 283 bonds on 2024-12-27.
# ✅ Valued 280 bonds on 2024-12-31.
# ✅ Valued 280 bonds on 2024-12-30.
# ✅ Valued 283 bonds on 2025-01-02.
# ✅ Valued 283 bonds on 2025-01-03.
# ✅ Valued 283 bonds on 2025-01-06.
# ✅ Valued 283 bonds on 2025-01-07.
# ✅ Valued 283 bonds on 2025-01-09.
# ✅ Valued 283 bonds on 2025-01-08.
# ✅ Valued 282 bonds on 2025-01-10.
# ✅ Valued 282 bonds on 2025-01-13.
# ✅ Valued 282 bonds on 2025-01-14.
# ✅ Valued 281 bonds on 2025-01-15.
# ✅ Valued 282 bonds on 2025-01-16.
# ✅ Valued 282 bonds on 2025-01-17.
# ✅ Valued 282 bonds on 2025-01-21.
# ✅ Valued 282 bonds on 2025-01-22.
# ✅ Valued 283 bonds on 2025-01-24.
# ✅ Valued 282 bonds on 2025-01-23.
# ✅ Valued 283 bonds on 2025-01-27.
# ✅ Valued 283 bonds on 2025-01-29.✅ Valued 283 bonds on 2025-01-30.
#
# ✅ Valued 283 bonds on 2025-01-28.
# ✅ Valued 280 bonds on 2025-01-31.
# ✅ Valued 283 bonds on 2025-02-03.
# ✅ Valued 283 bonds on 2025-02-06.
# ✅ Valued 283 bonds on 2025-02-05.
# ✅ Valued 283 bonds on 2025-02-04.
# ✅ Valued 282 bonds on 2025-02-07.
# ✅ Valued 282 bonds on 2025-02-10.
# ✅ Valued 282 bonds on 2025-02-11.
# ✅ Valued 282 bonds on 2025-02-13.
# ✅ Valued 282 bonds on 2025-02-12.
# ✅ Valued 282 bonds on 2025-02-14.
# ✅ Valued 280 bonds on 2025-02-18.
# ✅ Valued 283 bonds on 2025-02-20.
# ✅ Valued 283 bonds on 2025-02-19.
# ✅ Valued 284 bonds on 2025-02-21.
# ✅ Valued 284 bonds on 2025-02-26.
# ✅ Valued 284 bonds on 2025-02-27.
# ✅ Valued 284 bonds on 2025-02-25.
# ✅ Valued 284 bonds on 2025-02-24.
# ✅ Valued 284 bonds on 2025-03-03.
# ✅ Valued 284 bonds on 2025-02-28.
# ✅ Valued 283 bonds on 2025-03-04.
# ✅ Valued 283 bonds on 2025-03-05.
# ✅ Valued 283 bonds on 2025-03-07.
# ✅ Valued 283 bonds on 2025-03-06.
# ✅ Valued 283 bonds on 2025-03-11.
# ✅ Valued 283 bonds on 2025-03-10.
# ✅ Valued 283 bonds on 2025-03-12.
# ✅ Valued 283 bonds on 2025-03-13.
# ✅ Valued 283 bonds on 2025-03-14.
# ✅ Valued 282 bonds on 2025-03-17.
# ✅ Valued 283 bonds on 2025-03-18.
# ✅ Valued 283 bonds on 2025-03-19.
# ✅ Valued 283 bonds on 2025-03-20.
# ✅ Valued 284 bonds on 2025-03-21.
# ✅ Valued 284 bonds on 2025-03-24.
# ✅ Valued 284 bonds on 2025-03-25.
# ✅ Valued 284 bonds on 2025-03-26.
# ✅ Valued 284 bonds on 2025-03-28.
# ✅ Valued 284 bonds on 2025-03-27.
# ✅ Valued 284 bonds on 2025-04-01.
# ✅ Valued 281 bonds on 2025-03-31.
# ✅ Valued 283 bonds on 2025-04-03.
# ✅ Valued 283 bonds on 2025-04-02.
# ✅ Valued 283 bonds on 2025-04-04.
# ✅ Valued 283 bonds on 2025-04-08.
# ✅ Valued 283 bonds on 2025-04-07.
# ✅ Valued 283 bonds on 2025-04-09.
# ✅ Valued 283 bonds on 2025-04-10.
# ✅ Valued 283 bonds on 2025-04-11.
# ✅ Valued 283 bonds on 2025-04-14.
# ✅ Valued 282 bonds on 2025-04-15.
# ✅ Valued 283 bonds on 2025-04-16.
# ✅ Valued 283 bonds on 2025-04-17.
# ✅ Valued 284 bonds on 2025-04-21.
# ✅ Valued 284 bonds on 2025-04-22.
# ✅ Valued 284 bonds on 2025-04-23.
# ✅ Valued 284 bonds on 2025-04-24.
# ✅ Valued 284 bonds on 2025-04-25.
# ✅ Valued 284 bonds on 2025-04-28.
# ✅ Valued 283 bonds on 2025-04-30.
# ✅ Valued 283 bonds on 2025-05-01.
# ✅ Valued 284 bonds on 2025-04-29.
# ✅ Valued 283 bonds on 2025-05-02.
# ✅ Valued 283 bonds on 2025-05-05.
# ✅ Valued 283 bonds on 2025-05-07.
# ✅ Valued 283 bonds on 2025-05-08.
# ✅ Valued 283 bonds on 2025-05-06.
# ✅ Valued 283 bonds on 2025-05-09.
# ✅ Valued 283 bonds on 2025-05-12.
# ✅ Valued 283 bonds on 2025-05-13.
# ✅ Valued 281 bonds on 2025-05-15.
# ✅ Valued 283 bonds on 2025-05-14.
# ✅ Valued 285 bonds on 2025-05-16.
# ✅ Valued 285 bonds on 2025-05-19.
# ✅ Valued 285 bonds on 2025-05-20.
# ✅ Valued 285 bonds on 2025-05-21.
# ✅ Valued 285 bonds on 2025-05-22.
# ✅ Valued 285 bonds on 2025-05-23.
# ✅ Valued 284 bonds on 2025-05-28.
# ✅ Valued 285 bonds on 2025-05-27.
# ✅ Valued 284 bonds on 2025-05-29.
# ⚠️  234 dates failed:
#   • 2023-06-03: No yield curve data found for 2023-06-03
#   • 2023-06-04: No yield curve data found for 2023-06-04
#   • 2023-06-10: No yield curve data found for 2023-06-10
#   • 2023-06-11: No yield curve data found for 2023-06-11
#   • 2023-06-17: No yield curve data found for 2023-06-17
#   • 2023-06-18: No yield curve data found for 2023-06-18
#   • 2023-06-19: No yield curve data found for 2023-06-19
#   • 2023-06-24: No yield curve data found for 2023-06-24
#   • 2023-06-25: No yield curve data found for 2023-06-25
#   • 2023-07-01: No yield curve data found for 2023-07-01
#   • 2023-07-02: No yield curve data found for 2023-07-02
#   • 2023-07-04: No yield curve data found for 2023-07-04
#   • 2023-07-08: No yield curve data found for 2023-07-08
#   • 2023-07-09: No yield curve data found for 2023-07-09
#   • 2023-07-15: No yield curve data found for 2023-07-15
#   • 2023-07-16: No yield curve data found for 2023-07-16
#   • 2023-07-22: No yield curve data found for 2023-07-22
#   • 2023-07-23: No yield curve data found for 2023-07-23
#   • 2023-07-30: No yield curve data found for 2023-07-30
#   • 2023-07-29: No yield curve data found for 2023-07-29
#   • 2023-08-05: No yield curve data found for 2023-08-05
#   • 2023-08-06: No yield curve data found for 2023-08-06
#   • 2023-08-12: No yield curve data found for 2023-08-12
#   • 2023-08-13: No yield curve data found for 2023-08-13
#   • 2023-08-19: No yield curve data found for 2023-08-19
#   • 2023-08-20: No yield curve data found for 2023-08-20
#   • 2023-08-26: No yield curve data found for 2023-08-26
#   • 2023-08-27: No yield curve data found for 2023-08-27
#   • 2023-09-02: No yield curve data found for 2023-09-02
#   • 2023-09-03: No yield curve data found for 2023-09-03
#   • 2023-09-04: No yield curve data found for 2023-09-04
#   • 2023-09-09: No yield curve data found for 2023-09-09
#   • 2023-09-10: No yield curve data found for 2023-09-10
#   • 2023-09-16: No yield curve data found for 2023-09-16
#   • 2023-09-17: No yield curve data found for 2023-09-17
#   • 2023-09-24: No yield curve data found for 2023-09-24
#   • 2023-09-23: No yield curve data found for 2023-09-23
#   • 2023-09-30: No yield curve data found for 2023-09-30
#   • 2023-10-01: No yield curve data found for 2023-10-01
#   • 2023-10-07: No yield curve data found for 2023-10-07
#   • 2023-10-08: No yield curve data found for 2023-10-08
#   • 2023-10-09: No yield curve data found for 2023-10-09
#   • 2023-10-14: No yield curve data found for 2023-10-14
#   • 2023-10-15: No yield curve data found for 2023-10-15
#   • 2023-10-21: No yield curve data found for 2023-10-21
#   • 2023-10-22: No yield curve data found for 2023-10-22
#   • 2023-10-28: No yield curve data found for 2023-10-28
#   • 2023-10-29: No yield curve data found for 2023-10-29
#   • 2023-11-04: No yield curve data found for 2023-11-04
#   • 2023-11-05: No yield curve data found for 2023-11-05
#   • 2023-11-11: No yield curve data found for 2023-11-11
#   • 2023-11-12: No yield curve data found for 2023-11-12
#   • 2023-11-18: No yield curve data found for 2023-11-18
#   • 2023-11-19: No yield curve data found for 2023-11-19
#   • 2023-11-23: No yield curve data found for 2023-11-23
#   • 2023-11-25: No yield curve data found for 2023-11-25
#   • 2023-11-26: No yield curve data found for 2023-11-26
#   • 2023-12-02: No yield curve data found for 2023-12-02
#   • 2023-12-03: No yield curve data found for 2023-12-03
#   • 2023-12-09: No yield curve data found for 2023-12-09
#   • 2023-12-10: No yield curve data found for 2023-12-10
#   • 2023-12-16: No yield curve data found for 2023-12-16
#   • 2023-12-17: No yield curve data found for 2023-12-17
#   • 2023-12-23: No yield curve data found for 2023-12-23
#   • 2023-12-24: No yield curve data found for 2023-12-24
#   • 2023-12-25: No yield curve data found for 2023-12-25
#   • 2023-12-30: No yield curve data found for 2023-12-30
#   • 2023-12-31: No yield curve data found for 2023-12-31
#   • 2024-01-01: No yield curve data found for 2024-01-01
#   • 2024-01-06: No yield curve data found for 2024-01-06
#   • 2024-01-07: No yield curve data found for 2024-01-07
#   • 2024-01-14: No yield curve data found for 2024-01-14
#   • 2024-01-13: No yield curve data found for 2024-01-13
#   • 2024-01-15: No yield curve data found for 2024-01-15
#   • 2024-01-21: No yield curve data found for 2024-01-21
#   • 2024-01-20: No yield curve data found for 2024-01-20
#   • 2024-01-27: No yield curve data found for 2024-01-27
#   • 2024-01-28: No yield curve data found for 2024-01-28
#   • 2024-02-03: No yield curve data found for 2024-02-03
#   • 2024-02-04: No yield curve data found for 2024-02-04
#   • 2024-02-10: No yield curve data found for 2024-02-10
#   • 2024-02-11: No yield curve data found for 2024-02-11
#   • 2024-02-17: No yield curve data found for 2024-02-17
#   • 2024-02-18: No yield curve data found for 2024-02-18
#   • 2024-02-19: No yield curve data found for 2024-02-19
#   • 2024-02-24: No yield curve data found for 2024-02-24
#   • 2024-02-25: No yield curve data found for 2024-02-25
#   • 2024-03-02: No yield curve data found for 2024-03-02
#   • 2024-03-03: No yield curve data found for 2024-03-03
#   • 2024-03-09: No yield curve data found for 2024-03-09
#   • 2024-03-10: No yield curve data found for 2024-03-10
#   • 2024-03-16: No yield curve data found for 2024-03-16
#   • 2024-03-17: No yield curve data found for 2024-03-17
#   • 2024-03-23: No yield curve data found for 2024-03-23
#   • 2024-03-24: No yield curve data found for 2024-03-24
#   • 2024-03-29: No yield curve data found for 2024-03-29
#   • 2024-03-30: No yield curve data found for 2024-03-30
#   • 2024-03-31: No yield curve data found for 2024-03-31
#   • 2024-04-06: No yield curve data found for 2024-04-06
#   • 2024-04-07: No yield curve data found for 2024-04-07
#   • 2024-04-13: No yield curve data found for 2024-04-13
#   • 2024-04-14: No yield curve data found for 2024-04-14
#   • 2024-04-20: No yield curve data found for 2024-04-20
#   • 2024-04-21: No yield curve data found for 2024-04-21
#   • 2024-04-27: No yield curve data found for 2024-04-27
#   • 2024-04-28: No yield curve data found for 2024-04-28
#   • 2024-05-04: No yield curve data found for 2024-05-04
#   • 2024-05-05: No yield curve data found for 2024-05-05
#   • 2024-05-11: No yield curve data found for 2024-05-11
#   • 2024-05-12: No yield curve data found for 2024-05-12
#   • 2024-05-18: No yield curve data found for 2024-05-18
#   • 2024-05-19: No yield curve data found for 2024-05-19
#   • 2024-05-25: No yield curve data found for 2024-05-25
#   • 2024-05-26: No yield curve data found for 2024-05-26
#   • 2024-05-27: No yield curve data found for 2024-05-27
#   • 2024-06-01: No yield curve data found for 2024-06-01
#   • 2024-06-02: No yield curve data found for 2024-06-02
#   • 2024-06-08: No yield curve data found for 2024-06-08
#   • 2024-06-09: No yield curve data found for 2024-06-09
#   • 2024-06-15: No yield curve data found for 2024-06-15
#   • 2024-06-16: No yield curve data found for 2024-06-16
#   • 2024-06-19: No yield curve data found for 2024-06-19
#   • 2024-06-22: No yield curve data found for 2024-06-22
#   • 2024-06-23: No yield curve data found for 2024-06-23
#   • 2024-06-29: No yield curve data found for 2024-06-29
#   • 2024-06-30: No yield curve data found for 2024-06-30
#   • 2024-07-04: No yield curve data found for 2024-07-04
#   • 2024-07-07: No yield curve data found for 2024-07-07
#   • 2024-07-06: No yield curve data found for 2024-07-06
#   • 2024-07-13: No yield curve data found for 2024-07-13
#   • 2024-07-14: No yield curve data found for 2024-07-14
#   • 2024-07-20: No yield curve data found for 2024-07-20
#   • 2024-07-21: No yield curve data found for 2024-07-21
#   • 2024-07-27: No yield curve data found for 2024-07-27
#   • 2024-07-28: No yield curve data found for 2024-07-28
#   • 2024-08-03: No yield curve data found for 2024-08-03
#   • 2024-08-04: No yield curve data found for 2024-08-04
#   • 2024-08-10: No yield curve data found for 2024-08-10
#   • 2024-08-11: No yield curve data found for 2024-08-11
#   • 2024-08-17: No yield curve data found for 2024-08-17
#   • 2024-08-18: No yield curve data found for 2024-08-18
#   • 2024-08-24: No yield curve data found for 2024-08-24
#   • 2024-08-25: No yield curve data found for 2024-08-25
#   • 2024-08-31: No yield curve data found for 2024-08-31
#   • 2024-09-01: No yield curve data found for 2024-09-01
#   • 2024-09-02: No yield curve data found for 2024-09-02
#   • 2024-09-08: No yield curve data found for 2024-09-08
#   • 2024-09-07: No yield curve data found for 2024-09-07
#   • 2024-09-14: No yield curve data found for 2024-09-14
#   • 2024-09-15: No yield curve data found for 2024-09-15
#   • 2024-09-21: No yield curve data found for 2024-09-21
#   • 2024-09-22: No yield curve data found for 2024-09-22
#   • 2024-09-28: No yield curve data found for 2024-09-28
#   • 2024-09-29: No yield curve data found for 2024-09-29
#   • 2024-10-05: No yield curve data found for 2024-10-05
#   • 2024-10-06: No yield curve data found for 2024-10-06
#   • 2024-10-12: No yield curve data found for 2024-10-12
#   • 2024-10-13: No yield curve data found for 2024-10-13
#   • 2024-10-14: No yield curve data found for 2024-10-14
#   • 2024-10-19: No yield curve data found for 2024-10-19
#   • 2024-10-20: No yield curve data found for 2024-10-20
#   • 2024-10-27: No yield curve data found for 2024-10-27
#   • 2024-10-26: No yield curve data found for 2024-10-26
#   • 2024-11-02: No yield curve data found for 2024-11-02
#   • 2024-11-03: No yield curve data found for 2024-11-03
#   • 2024-11-09: No yield curve data found for 2024-11-09
#   • 2024-11-10: No yield curve data found for 2024-11-10
#   • 2024-11-11: No yield curve data found for 2024-11-11
#   • 2024-11-16: No yield curve data found for 2024-11-16
#   • 2024-11-17: No yield curve data found for 2024-11-17
#   • 2024-11-23: No yield curve data found for 2024-11-23
#   • 2024-11-24: No yield curve data found for 2024-11-24
#   • 2024-11-28: No yield curve data found for 2024-11-28
#   • 2024-11-30: No yield curve data found for 2024-11-30
#   • 2024-12-01: No yield curve data found for 2024-12-01
#   • 2024-12-07: No yield curve data found for 2024-12-07
#   • 2024-12-08: No yield curve data found for 2024-12-08
#   • 2024-12-15: No yield curve data found for 2024-12-15
#   • 2024-12-14: No yield curve data found for 2024-12-14
#   • 2024-12-21: No yield curve data found for 2024-12-21
#   • 2024-12-22: No yield curve data found for 2024-12-22
#   • 2024-12-25: No yield curve data found for 2024-12-25
#   • 2024-12-29: No yield curve data found for 2024-12-29
#   • 2024-12-28: No yield curve data found for 2024-12-28
#   • 2025-01-01: No yield curve data found for 2025-01-01
#   • 2025-01-05: No yield curve data found for 2025-01-05
#   • 2025-01-04: No yield curve data found for 2025-01-04
#   • 2025-01-11: No yield curve data found for 2025-01-11
#   • 2025-01-12: No yield curve data found for 2025-01-12
#   • 2025-01-18: No yield curve data found for 2025-01-18
#   • 2025-01-19: No yield curve data found for 2025-01-19
#   • 2025-01-20: No yield curve data found for 2025-01-20
#   • 2025-01-25: No yield curve data found for 2025-01-25
#   • 2025-01-26: No yield curve data found for 2025-01-26
#   • 2025-02-01: No yield curve data found for 2025-02-01
#   • 2025-02-02: No yield curve data found for 2025-02-02
#   • 2025-02-09: No yield curve data found for 2025-02-09
#   • 2025-02-08: No yield curve data found for 2025-02-08
#   • 2025-02-15: No yield curve data found for 2025-02-15
#   • 2025-02-16: No yield curve data found for 2025-02-16
#   • 2025-02-17: No yield curve data found for 2025-02-17
#   • 2025-02-22: No yield curve data found for 2025-02-22
#   • 2025-02-23: No yield curve data found for 2025-02-23
#   • 2025-03-01: No yield curve data found for 2025-03-01
#   • 2025-03-02: No yield curve data found for 2025-03-02
#   • 2025-03-08: No yield curve data found for 2025-03-08
#   • 2025-03-09: No yield curve data found for 2025-03-09
#   • 2025-03-15: No yield curve data found for 2025-03-15
#   • 2025-03-16: No yield curve data found for 2025-03-16
#   • 2025-03-23: No yield curve data found for 2025-03-23
#   • 2025-03-22: No yield curve data found for 2025-03-22
#   • 2025-03-29: No yield curve data found for 2025-03-29
#   • 2025-03-30: No yield curve data found for 2025-03-30
#   • 2025-04-05: No yield curve data found for 2025-04-05
#   • 2025-04-06: No yield curve data found for 2025-04-06
#   • 2025-04-12: No yield curve data found for 2025-04-12
#   • 2025-04-13: No yield curve data found for 2025-04-13
#   • 2025-04-18: No yield curve data found for 2025-04-18
#   • 2025-04-19: No yield curve data found for 2025-04-19
#   • 2025-04-20: No yield curve data found for 2025-04-20
#   • 2025-04-26: No yield curve data found for 2025-04-26
#   • 2025-04-27: No yield curve data found for 2025-04-27
#   • 2025-05-03: No yield curve data found for 2025-05-03
#   • 2025-05-04: No yield curve data found for 2025-05-04
#   • 2025-05-11: No yield curve data found for 2025-05-11
#   • 2025-05-10: No yield curve data found for 2025-05-10
#   • 2025-05-17: No yield curve data found for 2025-05-17
#   • 2025-05-18: No yield curve data found for 2025-05-18
#   • 2025-05-24: No yield curve data found for 2025-05-24
#   • 2025-05-25: No yield curve data found for 2025-05-25
#   • 2025-05-26: No yield curve data found for 2025-05-26
#   • 2025-05-30: No yield curve data found for 2025-05-30
#   • 2025-05-31: No yield curve data found for 2025-05-31
#   • 2025-06-01: No yield curve data found for 2025-06-01
# 🏃 View run funny-ray-337 at: http://127.0.0.1:8768/#/experiments/1465/runs/42fdeea1defe40c2bb5c2c55fcc104be
# 🧪 View experiment at: http://127.0.0.1:8768/#/experiments/1465
# ✅ Backfill complete.

# %%
results
